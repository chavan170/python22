# %%
#write a python code to accept a string from the user and display the characters that are present at an even index number.

word = input('Enter word ')
print("Original String:", word)


x = list(word)
for i in x[0::2]:
    print(i)
# Out:
# Enter word welcome to kolhapur
# Original String: welcome to kolhapur
# w
# l
# o
# e
# t
#
# o
# h
# p
# r

# %%
#Write a python program to find the median of three values.
x = input("Input the first number: ")
y = input("Input the second number: ")
z = input("Input the third number: ")
print("Median of the above three numbers -")
if y < x and x < z:
    print(x)
elif z < x and x < y:
    print(x)
elif z < y and y < x:
    print(y)
elif x < y and y < z:
    print(y)
elif y < z and z < x:
    print(z)
elif x < z and z < y:
    print(z)
# Out:
# Input the first number: 23
# Input the second number: 64
# Input the third number: 98
# Median of the above three numbers -
# 64

# %%
# write a python program check if the first and last number of a list are the same
def first_last_same(numberList):
    print("Given list:", numberList)

    first_num = numberList[0]
    last_num = numberList[-1]

    if first_num == last_num:
        return True
    else:
        return False

numbers_x = [10, 20, 30, 40, 10]
print("result is", first_last_same(numbers_x))

numbers_y = [75, 65, 35, 75, 30]
print("result is", first_last_same(numbers_y))
# Out:
# Given list: [10, 20, 30, 40, 10]
# result is True
# Given list: [75, 65, 35, 75, 30]
# result is False

# %%
#write a python program to test whether a passed letter is a vowel or not
def is_vowel(char):
    all_vowels = 'aeiou'
    return char in all_vowels
print(is_vowel('c'))
print(is_vowel('e'))
# Out:
# False
# True

# %%
#write a python program to sum three given Integer.However if two value are equal sum will be zero
def sum_three(x,y,z):
    if x == y or y == z or x==z:
        sum = 0
    else:
        sum = x + y + z
    return sum

print(sum_three(59, 1, 56))
print(sum_three(3, 2, 6))
print(sum_three(2, 2, 2))
print(sum_three(1, 2, 3))
# Out:
# 116
# 11
# 0
# 6
